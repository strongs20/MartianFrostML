# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="6"

# %% [markdown]
# # Martian Frost HiRISE Image Classification
# * Data confidence weighting
# * Predicts frost_context probabilities
#
# Outside of built-in python 3 libraries, this code uses numpy, skimage, tqdm, PIL, matplotlib, and tensorflow.

# %%
import os
import os.path as op
import json
from pathlib import Path
import shutil
import logging

import numpy as np
from tqdm import tqdm
from skimage import io

# Logging configuration
logging.basicConfig(level=logging.INFO,
                    datefmt='%H:%M:%S',
                    format='%(asctime)s | %(levelname)-5s | %(module)-15s | %(message)s')

IMAGE_SIZE = (299, 299)  # All images contained in this dataset are 299x299 (originally, to match Inception v3 input size)
SEED = 17

# Head directory containing all image subframes
data_head_dir = Path('./data')

# Find all subframe directories
subdirs = [Path(subdir.stem) for subdir in data_head_dir.iterdir() if subdir.is_dir()]
src_image_ids = ['_'.join(a_path.name.split('_')[:3]) for a_path in subdirs]

# %% [markdown]
# # Suggested Data Split
#
# Use the suggested train/val/test split to avoid data leakage across each data subset from a geospatial perspective.

# %%
# Load train/val/test subframe IDs
def load_text_ids(file_path):
    """Simple helper to load all lines from a text file"""
    with open(file_path, 'r') as f:
        lines = [line.strip() for line in f.readlines()]
    return lines

# Load the subframe names for the three data subsets
train_ids = load_text_ids('./train_source_images.txt')
validate_ids = load_text_ids('./val_source_images.txt')
test_ids = load_text_ids('./test_source_images.txt')

# %% [markdown]
# ## Create frost context array helper functions
# These will help us decode and encode the frost context arrays that are stored in the jsons.
# Will also be used for data visualization

# %%
# [defrosting marks, halos, polygonal cracks, slab ice cracks, uniform albedo, other]
# convert string to index
def get_context_idx(str):
    if (str == 'defrosting_marks'):
        return 0
    elif (str == 'halos'):
        return 1
    elif (str == 'polygonal_cracks'):
        return 2
    elif (str == 'slab_ice_cracks'):
        return 3
    elif (str == 'uniform_albedo'):
        return 4
    elif (str == 'other'):
        return 5
    
# convert annotations to frost context entry
def get_category_format(data):
    entry = [0, 0, 0, 0, 0, 0]
    for k in range(len(data['frost_types'])):
        if data['frost_types'][k] == 'defrosting_marks':
            entry[0] = 1
        elif data['frost_types'][k] == 'halos':
            entry[1] = 1
        elif data['frost_types'][k] == 'polygonal_cracks':
            entry[2] = 1
        elif data['frost_types'][k] == 'slab_ice_cracks':
            entry[3] = 1
        elif data['frost_types'][k] == 'uniform_albedo':
            entry[4] = 1
        elif data['frost_types'][k] == 'other':
            entry[5] = 1
    return entry

# convert frost context entry to sentence for readability
def decode_array_to_context(arr):
    context = ''
    if arr[0] == 1:
        context += 'defrosting marks, '
    if arr[1] == 1:
        context += 'halos, '
    if arr[2] == 1:
        context += 'polygonal cracks, '
    if arr[3] == 1:
        context += 'slab ice cracks, '
    if arr[4] == 1:
        context += 'uniform albedo, '
    if arr[5] == 1:
        context += 'other, '
    # Remove the last 2 characters from the string
    context = context[:-2]
    if context == '':
        context = 'no frost'
    return context


def get_pred_format(arr):
    context = ''
    if arr[0] != 0:
        context += f'defrosting marks: {np.round(arr[0]*100)}%\n'
    if arr[1] != 0:
        context += f'halos: {np.round(arr[1]*100)}%\n'
    if arr[2] != 0:
        context += f'polygonal cracks: {np.round(arr[2]*100)}%\n'
    if arr[3] != 0:
        context += f'slab ice cracks: {np.round(arr[3]*100)}%\n'
    if arr[4] != 0:
        context += f'uniform albedo: {np.round(arr[4]*100)}%\n'
    if arr[5] != 0:
        context += f'other: {np.round(arr[5]*100)}%\n'
    # Remove the last newline from string
    if context == '':
        context = 'no frost (~0%)\n'
    context = context[:-1]
    return context

# %% [markdown]
# ## Prepare data as numpy arrays
#
# Load the data and pair a tile with its label. Each tile is stored in a numpy array under its parent. Each tile is a data object containing the following parameters:
# * `tile`: the png image data
# * `label`: the entire json for the tile
# * `class`: the class of the tile
# * `file`: the filename of the tile
# * `data`: the json annotations
# * `frost_types`: formatted 6-length array of frost contexts
#
# ## Add weight to labeller confidence
# * Low confidence: 4.0
# * Medium confidence: 7.0
# * High confidence: 1.0
# * Multiply by overlap proportion
# * Compute the average weight for each frost type with confidence
# Assign a cutoff value of 0.5. I.e. if the 'uniform_albedo' has
# a score of 0.8, consider it a 1. If it's 0.3, consider it a 0

# %%
from skimage import io, color
# modified this function to pair a tile with its label

# define the cutoff hyperparameter
cutoff = 0.5

def load_images(dir_path):

    tile_dir = dir_path / Path('tiles')
    images = {'file': dir_path.stem, 'class': '', 'tiles': []}

    for root, dirs, files in os.walk(tile_dir):
        for file in files:
            file = Path(file)
            if file.suffix == '.png':
                fp = os.path.join(root, file)
                
                # Extract the image class label from the filepath. This (and additional) info is also in the label jsons
                image_class = Path(root).stem
                if images['class'] == '':
                    images['class'] = image_class
                
                # Load the image, save it to our list

                img = io.imread(fp)

                if len(img.shape) == 2:  # check if the image is grayscale
                    img = color.gray2rgb(img)  # convert to RGB

                # locate the associated label json
                label_fp = op.join(dir_path, 'labels', image_class, f'{file.stem}.json')
                with open(label_fp, 'r') as f:
                    label_json = json.load(f)

                # determine what frost types are present
                frost_data = [0,0,0,0,0,0]
                # Get the polygons
                annotations = label_json['annotations']
                for i in range(len(annotations)):
                    this_overlap = annotations[i]['overlap_proportion']
                    weight = 0
                    if "low" in annotations[i]['confidence']:
                        weight = 0.4
                    elif "med" in annotations[i]['confidence']:
                        weight = 0.7
                    elif "high" in annotations[i]['confidence']:
                        weight = 1.0
                    for j in range(len(annotations[i]['frost_context'])):
                        frost_data[get_context_idx(annotations[i]
                                   ['frost_context'][j])] += (weight*this_overlap)
                
                # average the frost data
                # if it exists!
                if len(annotations) > 0:
                    frost_data = [x / len(annotations) for x in frost_data]

                # compute the hard value at which we consider it a 1
                # set to 0.5 for now
                for i in range(len(frost_data)):
                    if frost_data[i] >= cutoff:
                        frost_data[i] = 1
                    else:
                        frost_data[i] = 0

                combined_entry = {"tile": img,
                                  "data": label_json, 
                                  "class": image_class,
                                  "file": file.stem,
                                  "frost_types": frost_data}
                
                images['tiles'].append(combined_entry)

    return images

# %% [markdown]
# ## Split the data into train/val/test
# Make use of load_images above and bin the data properly. It will bin according to the txt files imported above.

# %%
train_data = []
validate_data = []
test_data = []
logging.info(f'Loading ML data from {len(subdirs)} subframes.')
for subdir in tqdm(subdirs, desc='Creating Dataset as Numpy array'):
    full_path = data_head_dir / subdir
    for i in range(len(train_ids)):
        if train_ids[i] in str(full_path):
            train_data.append(load_images(full_path))
    for j in range(len(validate_ids)):
        if validate_ids[j] in str(full_path):
            validate_data.append(load_images(full_path))
    for k in range(len(test_ids)):
        if test_ids[k] in str(full_path):
            test_data.append(load_images(full_path))
# Out:
# 08:57:23 | INFO  | 1632450843      | Loading ML data from 214 subframes.
# Creating Dataset as Numpy array: 100%|██████████| 214/214 [02:43<00:00,  1.31it/s]

# %% [markdown]
# ## Check the size of each bin
# Just to check and make sure we binned correctly!

# %%
if (len(train_data) + len(validate_data) + len(test_data)) != 214:
    print("Error: Data not loaded and/or binned correctly")
else:
    print("Good to go!")
    # print all lengths, and the amount with frost/background class
    print(f"    -> Train size: {len(train_data)}")
    print(f"    -> Validate size: {len(validate_data)}")
    print(
        f"    -> Test size: {len(test_data)}")
# Out:
# Good to go!
#     -> Train size: 102
#     -> Validate size: 55
#     -> Test size: 57

# %% [markdown]
# ## Print a random tile and its frost context
# Print a random tile and its data to make sure everything is working properly.

# %%
import matplotlib.pyplot as plt
import random

def display_random_image_and_json(some_data):
    # Pick a random image that has frost
    idx = random.choice(range(len(some_data)))
    tile_i = random.choice(range(len(some_data[idx]['tiles'])))
    img_dict = some_data[idx]['tiles'][tile_i]

    img = img_dict['tile']

    # Plot the image
    fig, ax = plt.subplots()
    ax.imshow(img)

    # Set the title
    ax.set_title(
        f"Filename: {img_dict['file']}\nFrost Context: {decode_array_to_context(img_dict['frost_types'])}")

    plt.show()


display_random_image_and_json(train_data)

# %% [markdown]
# ## Preprocess data

# %% [markdown]
# Gather and bin the data

# %%
# frost type categories = [defrosting marks, halos, polygonal cracks, slab ice cracks, uniform albedo, other]

# Train Data
X_train = []
y_train = []
for i in range(len(train_data)):
    for j in range(len(train_data[i]['tiles'])):
        X_train.append(train_data[i]['tiles'][j]['tile'])
        y_train.append(train_data[i]['tiles'][j]['frost_types'])

# Validate Data
X_val = []
y_val = []
for i in range(len(validate_data)):
    for j in range(len(validate_data[i]['tiles'])):
        X_val.append(validate_data[i]['tiles'][j]['tile'])
        y_val.append(validate_data[i]['tiles'][j]['frost_types'])

# Test Data
X_test = []
y_test = []
for i in range(len(test_data)):
    for j in range(len(test_data[i]['tiles'])):
        X_test.append(test_data[i]['tiles'][j]['tile'])
        y_test.append(test_data[i]['tiles'][j]['frost_types'])

# %% [markdown]
# Format the data

# %%
# Convert lists to numpy array
X_train = np.array(X_train)
X_val = np.array(X_val)
X_test = np.array(X_test)
y_train = np.array(y_train)
y_val = np.array(y_val)
y_test = np.array(y_test)

# Normalize the data
# X_train = X_train / 255.0
# X_val = X_val / 255.0
# X_test = X_test / 255.0

# # Reshape the data
# X_train = X_train.reshape(-1,299,299,1)
# X_val = X_val.reshape(-1, 299, 299, 1)
# X_test = X_test.reshape(-1, 299, 299, 1)

###### Shuffle the training set ######
indices = np.arange(X_train.shape[0])

# First shuffle the indices
np.random.shuffle(indices)

# Then use the shuffled indices to shuffle data and labels
X_train = X_train[indices]
y_train = y_train[indices]

# %% [markdown]
# Make sure it's formatted correctly

# %%
print(X_train.shape)
print(y_train.shape)
print(X_val.shape)
print(y_val.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (14119, 299, 299, 3)
# (14119, 6)
# (7889, 299, 299, 3)
# (7889, 6)
# (7972, 299, 299, 3)
# (7972, 6)

# %% [markdown]
# ## Import Tensorflow Packages

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %% [markdown]
# ## Augment the data

# %%
# Define the data augmentation parameters
aug_imgs = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True
)

aug_imgs.fit(X_train)

# %% [markdown]
# ## Fine Tune InceptionV3

# %%
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(299, 299, 3))

for layer in base_model.layers:
    layer.trainable = False
# Out:
# 2023-07-26 09:11:53.274627: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14585 MB memory:  -> device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:89:00.0, compute capability: 7.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 2s 0us/step

# %%
# Add a new top layer
x = base_model.output
x = Flatten()(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(1024, activation='relu')(x)
predictions = Dense(6, activation='sigmoid')(x)  # '6' is the number of classes

# This is the model we will train
model = Model(inputs=base_model.input, outputs=predictions)

# %%
import tensorflow as tf

def hamming_loss(y_true, y_pred):
    y_pred_binary = tf.cast(y_pred >= 0.5, dtype=tf.float32)
    elementwise_equal = tf.equal(y_true, y_pred_binary)
    false_count = tf.reduce_sum(
        tf.cast(tf.logical_not(elementwise_equal), dtype=tf.float32))
    # Divide by total number of labels
    loss = false_count / tf.cast(tf.size(y_true), dtype=tf.float32)
    return loss


def frost_presence_accuracy(y_true, y_pred):
    # Convert predictions to binary
    y_pred_binary = tf.cast(y_pred >= 0.5, dtype=tf.float32)

    # Compute sums of true and predicted labels
    y_true_sum = tf.reduce_sum(y_true, axis=-1)
    y_pred_sum = tf.reduce_sum(y_pred_binary, axis=-1)

    # Compute boolean tensors where True indicates that the sum of labels are either both zero or both non-zero
    sums_are_both_zero = tf.logical_and(
        tf.equal(y_true_sum, 0), tf.equal(y_pred_sum, 0))
    sums_are_both_non_zero = tf.logical_and(
        tf.not_equal(y_true_sum, 0), tf.not_equal(y_pred_sum, 0))

    # Combine the two conditions
    correct_condition = tf.logical_or(
        sums_are_both_zero, sums_are_both_non_zero)

    # Cast boolean tensor to float32 and compute mean
    accuracy = tf.reduce_mean(tf.cast(correct_condition, dtype=tf.float32))

    return accuracy

# %%
# Let's say you want a learning rate of 0.001
opt = Adam(learning_rate=0.001)

# Then compile the model
model.compile(optimizer=opt, loss='binary_crossentropy', metrics=[hamming_loss, frost_presence_accuracy])

# %%
batch_size = 24
epochs = 100

# %% [markdown]
# Give this roughly 3-4 minutes to run

# %%
# Assuming you already have the corresponding labels in y_train, y_val, y_test
train_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
valid_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_generator = train_datagen.flow(
    X_train,
    y_train,
    batch_size=batch_size)

validation_generator = valid_datagen.flow(
    X_val,
    y_val,
    batch_size=batch_size)

test_generator = test_datagen.flow(
    X_test,
    y_test,
    batch_size=1,
    shuffle=False)

# %% [markdown]
# ## Train the model

# %%
# early_stop = EarlyStopping(monitor='val_loss', patience=5)
max_steps = len(X_train) // batch_size
steps = max_steps // 10

history = model.fit(
    train_generator,
    steps_per_epoch = steps,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps = steps)
# Out:
# Epoch 1/100
# 2023-07-26 09:24:40.956608: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 58/58 [==============================] - ETA: 0s - loss: 0.5008 - hamming_loss: 0.0883 - frost_presence_accuracy: 0.7831
# 2023-07-26 09:25:18.841139: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 58/58 [==============================] - 84s 1s/step - loss: 0.5008 - hamming_loss: 0.0883 - frost_presence_accuracy: 0.7831 - val_loss: 0.3118 - val_hamming_loss: 0.1087 - val_frost_presence_accuracy: 0.6119
# Epoch 2/100
# 58/58 [==============================] - 95s 2s/step - loss: 0.0988 - hamming_loss: 0.0402 - frost_presence_accuracy: 0.8957 - val_loss: 0.4185 - val_hamming_loss: 0.1642 - val_frost_presence_accuracy: 0.4719
# Epoch 3/100
# 58/58 [==============================] - 99s 2s/step - loss: 0.0866 - hamming_loss: 0.0356 - frost_presence_accuracy: 0.9047 - val_loss: 0.5972 - val_hamming_loss: 0.2108 - val_frost_presence_accuracy: 0.3962
# Epoch 4/100
# 58/58 [==============================] - 68s 1s/step - loss: 0.0783 - hamming_loss: 0.0319 - frost_presence_accuracy: 0.9226 - val_loss: 0.4520 - val_hamming_loss: 0.1401 - val_frost_presence_accuracy: 0.5497
# Epoch 5/100
# 58/58 [==============================] - 110s 2s/step - loss: 0.0800 - hamming_loss: 0.0315 - frost_presence_accuracy: 0.9255 - val_loss: 0.3555 - val_hamming_loss: 0.1048 - val_frost_presence_accuracy: 0.6267
# Epoch 6/100
# 58/58 [==============================] - 105s 2s/step - loss: 0.0780 - hamming_loss: 0.0315 - frost_presence_accuracy: 0.9181 - val_loss: 0.3104 - val_hamming_loss: 0.0934 - val_frost_presence_accuracy: 0.6328
# Epoch 7/100
# 58/58 [==============================] - 104s 2s/step - loss: 0.0764 - hamming_loss: 0.0318 - frost_presence_accuracy: 0.9216 - val_loss: 0.3733 - val_hamming_loss: 0.1163 - val_frost_presence_accuracy: 0.5891
# Epoch 8/100
# 58/58 [==============================] - 135s 2s/step - loss: 0.0787 - hamming_loss: 0.0328 - frost_presence_accuracy: 0.9217 - val_loss: 0.4990 - val_hamming_loss: 0.1378 - val_frost_presence_accuracy: 0.4981
# Epoch 9/100
# 58/58 [==============================] - 34s 593ms/step - loss: 0.0769 - hamming_loss: 0.0311 - frost_presence_accuracy: 0.9255 - val_loss: 0.5031 - val_hamming_loss: 0.1301 - val_frost_presence_accuracy: 0.5626
# Epoch 10/100
# 58/58 [==============================] - 34s 591ms/step - loss: 0.0731 - hamming_loss: 0.0303 - frost_presence_accuracy: 0.9198 - val_loss: 0.5822 - val_hamming_loss: 0.1333 - val_frost_presence_accuracy: 0.5233
# Epoch 11/100
# 58/58 [==============================] - 33s 576ms/step - loss: 0.0782 - hamming_loss: 0.0316 - frost_presence_accuracy: 0.9191 - val_loss: 0.7952 - val_hamming_loss: 0.2002 - val_frost_presence_accuracy: 0.4119
# Epoch 12/100
# 58/58 [==============================] - 69s 1s/step - loss: 0.0758 - hamming_loss: 0.0307 - frost_presence_accuracy: 0.9233 - val_loss: 0.5487 - val_hamming_loss: 0.1140 - val_frost_presence_accuracy: 0.5850
# Epoch 13/100
# 58/58 [==============================] - 33s 577ms/step - loss: 0.0709 - hamming_loss: 0.0281 - frost_presence_accuracy: 0.9309 - val_loss: 0.6335 - val_hamming_loss: 0.1129 - val_frost_presence_accuracy: 0.5959
# Epoch 14/100
# 58/58 [==============================] - 68s 1s/step - loss: 0.0741 - hamming_loss: 0.0305 - frost_presence_accuracy: 0.9255 - val_loss: 0.6304 - val_hamming_loss: 0.1254 - val_frost_presence_accuracy: 0.5110
# Epoch 15/100
# 58/58 [==============================] - 42s 709ms/step - loss: 0.0722 - hamming_loss: 0.0311 - frost_presence_accuracy: 0.9212 - val_loss: 0.4575 - val_hamming_loss: 0.0867 - val_frost_presence_accuracy: 0.6783
# Epoch 16/100
# 58/58 [==============================] - 34s 584ms/step - loss: 0.0776 - hamming_loss: 0.0332 - frost_presence_accuracy: 0.9211 - val_loss: 0.6815 - val_hamming_loss: 0.1350 - val_frost_presence_accuracy: 0.5334
# Epoch 17/100
# 58/58 [==============================] - 34s 581ms/step - loss: 0.0755 - hamming_loss: 0.0323 - frost_presence_accuracy: 0.9175 - val_loss: 0.6056 - val_hamming_loss: 0.0977 - val_frost_presence_accuracy: 0.6614
# Epoch 18/100
# 58/58 [==============================] - 93s 2s/step - loss: 0.0778 - hamming_loss: 0.0342 - frost_presence_accuracy: 0.9162 - val_loss: 0.6440 - val_hamming_loss: 0.1470 - val_frost_presence_accuracy: 0.4916
# Epoch 19/100
# 58/58 [==============================] - 57s 992ms/step - loss: 0.0793 - hamming_loss: 0.0348 - frost_presence_accuracy: 0.9153 - val_loss: 0.5455 - val_hamming_loss: 0.1281 - val_frost_presence_accuracy: 0.6179
# Epoch 20/100
# 58/58 [==============================] - 38s 664ms/step - loss: 0.0697 - hamming_loss: 0.0297 - frost_presence_accuracy: 0.9283 - val_loss: 0.5074 - val_hamming_loss: 0.1054 - val_frost_presence_accuracy: 0.6074
# Epoch 21/100
# 58/58 [==============================] - 61s 1s/step - loss: 0.0684 - hamming_loss: 0.0297 - frost_presence_accuracy: 0.9274 - val_loss: 0.5352 - val_hamming_loss: 0.1419 - val_frost_presence_accuracy: 0.5838
# Epoch 22/100
# 58/58 [==============================] - 55s 956ms/step - loss: 0.0763 - hamming_loss: 0.0342 - frost_presence_accuracy: 0.9145 - val_loss: 0.5157 - val_hamming_loss: 0.1054 - val_frost_presence_accuracy: 0.6526
# Epoch 23/100
# 58/58 [==============================] - 87s 2s/step - loss: 0.0749 - hamming_loss: 0.0341 - frost_presence_accuracy: 0.9162 - val_loss: 0.5862 - val_hamming_loss: 0.1332 - val_frost_presence_accuracy: 0.5229
# Epoch 24/100
# 58/58 [==============================] - 32s 556ms/step - loss: 0.0717 - hamming_loss: 0.0327 - frost_presence_accuracy: 0.9211 - val_loss: 0.4652 - val_hamming_loss: 0.1094 - val_frost_presence_accuracy: 0.6233
# Epoch 25/100
# 58/58 [==============================] - 32s 561ms/step - loss: 0.0790 - hamming_loss: 0.0349 - frost_presence_accuracy: 0.9169 - val_loss: 0.4951 - val_hamming_loss: 0.1047 - val_frost_presence_accuracy: 0.6497
# Epoch 26/100
# 58/58 [==============================] - 40s 698ms/step - loss: 0.0817 - hamming_loss: 0.0334 - frost_presence_accuracy: 0.9181 - val_loss: 0.5828 - val_hamming_loss: 0.0751 - val_frost_presence_accuracy: 0.7326
# Epoch 27/100
# 58/58 [==============================] - 33s 569ms/step - loss: 0.0852 - hamming_loss: 0.0407 - frost_presence_accuracy: 0.8996 - val_loss: 0.4695 - val_hamming_loss: 0.0991 - val_frost_presence_accuracy: 0.6319
# Epoch 28/100
# 58/58 [==============================] - 37s 635ms/step - loss: 0.0794 - hamming_loss: 0.0370 - frost_presence_accuracy: 0.9080 - val_loss: 0.5138 - val_hamming_loss: 0.1543 - val_frost_presence_accuracy: 0.5102
# Epoch 29/100
# 58/58 [==============================] - 33s 571ms/step - loss: 0.0788 - hamming_loss: 0.0357 - frost_presence_accuracy: 0.9108 - val_loss: 0.4884 - val_hamming_loss: 0.1121 - val_frost_presence_accuracy: 0.6171
# Epoch 30/100
# 58/58 [==============================] - 33s 574ms/step - loss: 0.0755 - hamming_loss: 0.0342 - frost_presence_accuracy: 0.9150 - val_loss: 0.5255 - val_hamming_loss: 0.1289 - val_frost_presence_accuracy: 0.5407
# Epoch 31/100
# 58/58 [==============================] - 33s 561ms/step - loss: 0.0776 - hamming_loss: 0.0352 - frost_presence_accuracy: 0.9119 - val_loss: 0.5169 - val_hamming_loss: 0.0890 - val_frost_presence_accuracy: 0.6750
# Epoch 32/100
# 58/58 [==============================] - 32s 550ms/step - loss: 0.0707 - hamming_loss: 0.0315 - frost_presence_accuracy: 0.9191 - val_loss: 0.6017 - val_hamming_loss: 0.1287 - val_frost_presence_accuracy: 0.6278
# Epoch 33/100
# 58/58 [==============================] - 33s 562ms/step - loss: 0.0688 - hamming_loss: 0.0291 - frost_presence_accuracy: 0.9274 - val_loss: 0.5787 - val_hamming_loss: 0.1470 - val_frost_presence_accuracy: 0.4931
# Epoch 34/100
# 58/58 [==============================] - 32s 558ms/step - loss: 0.0661 - hamming_loss: 0.0277 - frost_presence_accuracy: 0.9356 - val_loss: 0.7396 - val_hamming_loss: 0.1227 - val_frost_presence_accuracy: 0.5978
# Epoch 35/100
# 58/58 [==============================] - 34s 593ms/step - loss: 0.0658 - hamming_loss: 0.0287 - frost_presence_accuracy: 0.9321 - val_loss: 0.5189 - val_hamming_loss: 0.0968 - val_frost_presence_accuracy: 0.6631
# Epoch 36/100
# 58/58 [==============================] - 35s 597ms/step - loss: 0.0638 - hamming_loss: 0.0272 - frost_presence_accuracy: 0.9345 - val_loss: 0.5883 - val_hamming_loss: 0.0997 - val_frost_presence_accuracy: 0.6578
# Epoch 37/100
# 58/58 [==============================] - 48s 825ms/step - loss: 0.0625 - hamming_loss: 0.0263 - frost_presence_accuracy: 0.9355 - val_loss: 0.6649 - val_hamming_loss: 0.0846 - val_frost_presence_accuracy: 0.6860
# Epoch 38/100
# 58/58 [==============================] - 66s 1s/step - loss: 0.0669 - hamming_loss: 0.0271 - frost_presence_accuracy: 0.9340 - val_loss: 0.5610 - val_hamming_loss: 0.0822 - val_frost_presence_accuracy: 0.6943
# Epoch 39/100
# 58/58 [==============================] - 34s 578ms/step - loss: 0.0763 - hamming_loss: 0.0329 - frost_presence_accuracy: 0.9206 - val_loss: 0.6390 - val_hamming_loss: 0.0998 - val_frost_presence_accuracy: 0.6679
# Epoch 40/100
# 58/58 [==============================] - 33s 573ms/step - loss: 0.0692 - hamming_loss: 0.0301 - frost_presence_accuracy: 0.9264 - val_loss: 0.5579 - val_hamming_loss: 0.0730 - val_frost_presence_accuracy: 0.7624
# Epoch 41/100
# 58/58 [==============================] - 45s 786ms/step - loss: 0.0634 - hamming_loss: 0.0263 - frost_presence_accuracy: 0.9362 - val_loss: 0.7375 - val_hamming_loss: 0.1570 - val_frost_presence_accuracy: 0.5638
# Epoch 42/100
# 58/58 [==============================] - 34s 582ms/step - loss: 0.0635 - hamming_loss: 0.0267 - frost_presence_accuracy: 0.9352 - val_loss: 0.6460 - val_hamming_loss: 0.1277 - val_frost_presence_accuracy: 0.5750
# Epoch 43/100
# 58/58 [==============================] - 33s 569ms/step - loss: 0.0618 - hamming_loss: 0.0290 - frost_presence_accuracy: 0.9255 - val_loss: 0.7041 - val_hamming_loss: 0.1496 - val_frost_presence_accuracy: 0.5712
# Epoch 44/100
# 58/58 [==============================] - 33s 575ms/step - loss: 0.0608 - hamming_loss: 0.0266 - frost_presence_accuracy: 0.9331 - val_loss: 0.5890 - val_hamming_loss: 0.1012 - val_frost_presence_accuracy: 0.6603
# Epoch 45/100
# 58/58 [==============================] - 33s 566ms/step - loss: 0.0609 - hamming_loss: 0.0276 - frost_presence_accuracy: 0.9336 - val_loss: 0.6217 - val_hamming_loss: 0.1111 - val_frost_presence_accuracy: 0.5569
# Epoch 46/100
# 58/58 [==============================] - 33s 569ms/step - loss: 0.0555 - hamming_loss: 0.0242 - frost_presence_accuracy: 0.9402 - val_loss: 0.6421 - val_hamming_loss: 0.0906 - val_frost_presence_accuracy: 0.6833
# Epoch 47/100
# 58/58 [==============================] - 33s 571ms/step - loss: 0.0542 - hamming_loss: 0.0230 - frost_presence_accuracy: 0.9459 - val_loss: 0.6766 - val_hamming_loss: 0.1278 - val_frost_presence_accuracy: 0.5898
# Epoch 48/100
# 58/58 [==============================] - 33s 573ms/step - loss: 0.0587 - hamming_loss: 0.0261 - frost_presence_accuracy: 0.9384 - val_loss: 0.6455 - val_hamming_loss: 0.0802 - val_frost_presence_accuracy: 0.6988
# Epoch 49/100
# 58/58 [==============================] - 33s 568ms/step - loss: 0.0539 - hamming_loss: 0.0236 - frost_presence_accuracy: 0.9431 - val_loss: 0.7511 - val_hamming_loss: 0.1105 - val_frost_presence_accuracy: 0.5748
# Epoch 50/100
# 58/58 [==============================] - 33s 562ms/step - loss: 0.0567 - hamming_loss: 0.0255 - frost_presence_accuracy: 0.9426 - val_loss: 0.6919 - val_hamming_loss: 0.0977 - val_frost_presence_accuracy: 0.6481
# Epoch 51/100
# 58/58 [==============================] - 33s 564ms/step - loss: 0.0569 - hamming_loss: 0.0256 - frost_presence_accuracy: 0.9395 - val_loss: 0.6886 - val_hamming_loss: 0.1174 - val_frost_presence_accuracy: 0.6059
# Epoch 52/100
# 58/58 [==============================] - 33s 567ms/step - loss: 0.0563 - hamming_loss: 0.0245 - frost_presence_accuracy: 0.9438 - val_loss: 0.7584 - val_hamming_loss: 0.1051 - val_frost_presence_accuracy: 0.6590
# Epoch 53/100
# 58/58 [==============================] - 33s 573ms/step - loss: 0.0569 - hamming_loss: 0.0251 - frost_presence_accuracy: 0.9470 - val_loss: 0.7134 - val_hamming_loss: 0.1058 - val_frost_presence_accuracy: 0.6505
# Epoch 54/100
# 58/58 [==============================] - 33s 570ms/step - loss: 0.0620 - hamming_loss: 0.0267 - frost_presence_accuracy: 0.9346 - val_loss: 0.5382 - val_hamming_loss: 0.0865 - val_frost_presence_accuracy: 0.6950
# Epoch 55/100
# 58/58 [==============================] - 33s 573ms/step - loss: 0.0596 - hamming_loss: 0.0261 - frost_presence_accuracy: 0.9353 - val_loss: 0.7660 - val_hamming_loss: 0.1419 - val_frost_presence_accuracy: 0.5276
# Epoch 56/100
# 58/58 [==============================] - 33s 565ms/step - loss: 0.0569 - hamming_loss: 0.0255 - frost_presence_accuracy: 0.9389 - val_loss: 0.5124 - val_hamming_loss: 0.0775 - val_frost_presence_accuracy: 0.7159
# Epoch 57/100
# 58/58 [==============================] - 33s 564ms/step - loss: 0.0508 - hamming_loss: 0.0223 - frost_presence_accuracy: 0.9467 - val_loss: 0.7013 - val_hamming_loss: 0.1087 - val_frost_presence_accuracy: 0.5364
# Epoch 58/100
# 58/58 [==============================] - 43s 738ms/step - loss: 0.0548 - hamming_loss: 0.0243 - frost_presence_accuracy: 0.9425 - val_loss: 0.8655 - val_hamming_loss: 0.1467 - val_frost_presence_accuracy: 0.5767
# Epoch 59/100
# 58/58 [==============================] - 38s 652ms/step - loss: 0.0607 - hamming_loss: 0.0282 - frost_presence_accuracy: 0.9314 - val_loss: 0.7704 - val_hamming_loss: 0.1172 - val_frost_presence_accuracy: 0.6276
# Epoch 60/100
# 58/58 [==============================] - 34s 580ms/step - loss: 0.0570 - hamming_loss: 0.0264 - frost_presence_accuracy: 0.9407 - val_loss: 0.7923 - val_hamming_loss: 0.1199 - val_frost_presence_accuracy: 0.6243
# Epoch 61/100
# 58/58 [==============================] - 33s 568ms/step - loss: 0.0522 - hamming_loss: 0.0234 - frost_presence_accuracy: 0.9440 - val_loss: 0.5957 - val_hamming_loss: 0.0792 - val_frost_presence_accuracy: 0.7143
# Epoch 62/100
# 58/58 [==============================] - 33s 568ms/step - loss: 0.0550 - hamming_loss: 0.0234 - frost_presence_accuracy: 0.9439 - val_loss: 0.7051 - val_hamming_loss: 0.1288 - val_frost_presence_accuracy: 0.5631
# Epoch 63/100
# 58/58 [==============================] - 41s 710ms/step - loss: 0.0607 - hamming_loss: 0.0275 - frost_presence_accuracy: 0.9346 - val_loss: 0.7250 - val_hamming_loss: 0.1268 - val_frost_presence_accuracy: 0.6767
# Epoch 64/100
# 58/58 [==============================] - 88s 2s/step - loss: 0.0584 - hamming_loss: 0.0288 - frost_presence_accuracy: 0.9350 - val_loss: 0.7542 - val_hamming_loss: 0.0771 - val_frost_presence_accuracy: 0.7469
# Epoch 65/100
# 58/58 [==============================] - 40s 698ms/step - loss: 0.0597 - hamming_loss: 0.0293 - frost_presence_accuracy: 0.9319 - val_loss: 0.8821 - val_hamming_loss: 0.1428 - val_frost_presence_accuracy: 0.5803
# Epoch 66/100
# 58/58 [==============================] - 88s 2s/step - loss: 0.0511 - hamming_loss: 0.0252 - frost_presence_accuracy: 0.9391 - val_loss: 0.8662 - val_hamming_loss: 0.1517 - val_frost_presence_accuracy: 0.5519
# Epoch 67/100
# 58/58 [==============================] - 34s 587ms/step - loss: 0.0537 - hamming_loss: 0.0259 - frost_presence_accuracy: 0.9352 - val_loss: 0.6067 - val_hamming_loss: 0.0757 - val_frost_presence_accuracy: 0.7222
# Epoch 68/100
# 58/58 [==============================] - 34s 594ms/step - loss: 0.0541 - hamming_loss: 0.0278 - frost_presence_accuracy: 0.9360 - val_loss: 0.6607 - val_hamming_loss: 0.1172 - val_frost_presence_accuracy: 0.6245
# Epoch 69/100
# 58/58 [==============================] - 34s 580ms/step - loss: 0.0531 - hamming_loss: 0.0256 - frost_presence_accuracy: 0.9333 - val_loss: 0.9524 - val_hamming_loss: 0.1608 - val_frost_presence_accuracy: 0.5857
# Epoch 70/100
# 58/58 [==============================] - 33s 575ms/step - loss: 0.0543 - hamming_loss: 0.0288 - frost_presence_accuracy: 0.9231 - val_loss: 0.6442 - val_hamming_loss: 0.0990 - val_frost_presence_accuracy: 0.6531
# Epoch 71/100
# 58/58 [==============================] - 33s 573ms/step - loss: 0.0632 - hamming_loss: 0.0311 - frost_presence_accuracy: 0.9260 - val_loss: 0.5572 - val_hamming_loss: 0.1170 - val_frost_presence_accuracy: 0.5864
# Epoch 72/100
# 58/58 [==============================] - 34s 579ms/step - loss: 0.0580 - hamming_loss: 0.0284 - frost_presence_accuracy: 0.9278 - val_loss: 0.6846 - val_hamming_loss: 0.1221 - val_frost_presence_accuracy: 0.6783
# Epoch 73/100
# 58/58 [==============================] - 33s 574ms/step - loss: 0.0561 - hamming_loss: 0.0282 - frost_presence_accuracy: 0.9357 - val_loss: 0.5782 - val_hamming_loss: 0.1231 - val_frost_presence_accuracy: 0.5698
# Epoch 74/100
# 58/58 [==============================] - 54s 931ms/step - loss: 0.0557 - hamming_loss: 0.0277 - frost_presence_accuracy: 0.9347 - val_loss: 0.6495 - val_hamming_loss: 0.1308 - val_frost_presence_accuracy: 0.5900
# Epoch 75/100
# 58/58 [==============================] - 76s 1s/step - loss: 0.0547 - hamming_loss: 0.0265 - frost_presence_accuracy: 0.9366 - val_loss: 0.5079 - val_hamming_loss: 0.0826 - val_frost_presence_accuracy: 0.7010
# Epoch 76/100
# 58/58 [==============================] - 34s 594ms/step - loss: 0.0573 - hamming_loss: 0.0283 - frost_presence_accuracy: 0.9359 - val_loss: 0.6002 - val_hamming_loss: 0.1182 - val_frost_presence_accuracy: 0.5981
# Epoch 77/100
# 58/58 [==============================] - 34s 590ms/step - loss: 0.0587 - hamming_loss: 0.0275 - frost_presence_accuracy: 0.9362 - val_loss: 0.6750 - val_hamming_loss: 0.0987 - val_frost_presence_accuracy: 0.6569
# Epoch 78/100
# 58/58 [==============================] - 103s 2s/step - loss: 0.0574 - hamming_loss: 0.0276 - frost_presence_accuracy: 0.9355 - val_loss: 0.6775 - val_hamming_loss: 0.1270 - val_frost_presence_accuracy: 0.6200
# Epoch 79/100
# 58/58 [==============================] - 51s 888ms/step - loss: 0.0558 - hamming_loss: 0.0275 - frost_presence_accuracy: 0.9339 - val_loss: 0.6672 - val_hamming_loss: 0.1018 - val_frost_presence_accuracy: 0.6338
# Epoch 80/100
# 58/58 [==============================] - 34s 591ms/step - loss: 0.0555 - hamming_loss: 0.0262 - frost_presence_accuracy: 0.9376 - val_loss: 0.7495 - val_hamming_loss: 0.1466 - val_frost_presence_accuracy: 0.5547
# Epoch 81/100
# 58/58 [==============================] - 35s 600ms/step - loss: 0.0523 - hamming_loss: 0.0258 - frost_presence_accuracy: 0.9396 - val_loss: 0.7165 - val_hamming_loss: 0.1221 - val_frost_presence_accuracy: 0.6272
# Epoch 82/100
# 58/58 [==============================] - 35s 605ms/step - loss: 0.0532 - hamming_loss: 0.0269 - frost_presence_accuracy: 0.9385 - val_loss: 0.6978 - val_hamming_loss: 0.1189 - val_frost_presence_accuracy: 0.6247
# Epoch 83/100
# 58/58 [==============================] - 35s 606ms/step - loss: 0.0614 - hamming_loss: 0.0292 - frost_presence_accuracy: 0.9369 - val_loss: 0.7476 - val_hamming_loss: 0.0913 - val_frost_presence_accuracy: 0.6909
# Epoch 84/100
# 58/58 [==============================] - 37s 630ms/step - loss: 0.0581 - hamming_loss: 0.0276 - frost_presence_accuracy: 0.9405 - val_loss: 0.6955 - val_hamming_loss: 0.1105 - val_frost_presence_accuracy: 0.6462
# Epoch 85/100
# 58/58 [==============================] - 36s 614ms/step - loss: 0.0560 - hamming_loss: 0.0266 - frost_presence_accuracy: 0.9416 - val_loss: 0.5394 - val_hamming_loss: 0.1000 - val_frost_presence_accuracy: 0.6466
# Epoch 86/100
# 58/58 [==============================] - 36s 613ms/step - loss: 0.0580 - hamming_loss: 0.0284 - frost_presence_accuracy: 0.9347 - val_loss: 0.7496 - val_hamming_loss: 0.1269 - val_frost_presence_accuracy: 0.5493
# Epoch 87/100
# 58/58 [==============================] - 80s 1s/step - loss: 0.0541 - hamming_loss: 0.0271 - frost_presence_accuracy: 0.9358 - val_loss: 0.8085 - val_hamming_loss: 0.1255 - val_frost_presence_accuracy: 0.6019
# Epoch 88/100
# 58/58 [==============================] - 147s 3s/step - loss: 0.0535 - hamming_loss: 0.0258 - frost_presence_accuracy: 0.9391 - val_loss: 0.6475 - val_hamming_loss: 0.0966 - val_frost_presence_accuracy: 0.6748
# Epoch 89/100
# 58/58 [==============================] - 59s 1s/step - loss: 0.0510 - hamming_loss: 0.0236 - frost_presence_accuracy: 0.9426 - val_loss: 0.7305 - val_hamming_loss: 0.1074 - val_frost_presence_accuracy: 0.6250
# Epoch 90/100
# 58/58 [==============================] - 38s 657ms/step - loss: 0.0534 - hamming_loss: 0.0269 - frost_presence_accuracy: 0.9372 - val_loss: 0.7456 - val_hamming_loss: 0.1112 - val_frost_presence_accuracy: 0.6097
# Epoch 91/100
# 58/58 [==============================] - 35s 609ms/step - loss: 0.0565 - hamming_loss: 0.0277 - frost_presence_accuracy: 0.9364 - val_loss: 0.5942 - val_hamming_loss: 0.0941 - val_frost_presence_accuracy: 0.6555
# Epoch 92/100
# 58/58 [==============================] - 34s 584ms/step - loss: 0.0598 - hamming_loss: 0.0292 - frost_presence_accuracy: 0.9330 - val_loss: 0.6870 - val_hamming_loss: 0.0749 - val_frost_presence_accuracy: 0.7241
# Epoch 93/100
# 58/58 [==============================] - 87s 2s/step - loss: 0.0550 - hamming_loss: 0.0267 - frost_presence_accuracy: 0.9402 - val_loss: 0.6456 - val_hamming_loss: 0.1078 - val_frost_presence_accuracy: 0.6240
# Epoch 94/100
# 58/58 [==============================] - 53s 913ms/step - loss: 0.0534 - hamming_loss: 0.0264 - frost_presence_accuracy: 0.9383 - val_loss: 0.7169 - val_hamming_loss: 0.0977 - val_frost_presence_accuracy: 0.6860
# Epoch 95/100
# 58/58 [==============================] - 74s 1s/step - loss: 0.0519 - hamming_loss: 0.0251 - frost_presence_accuracy: 0.9343 - val_loss: 0.6885 - val_hamming_loss: 0.1080 - val_frost_presence_accuracy: 0.6500
# Epoch 96/100
# 58/58 [==============================] - 36s 624ms/step - loss: 0.0489 - hamming_loss: 0.0231 - frost_presence_accuracy: 0.9464 - val_loss: 0.7457 - val_hamming_loss: 0.1056 - val_frost_presence_accuracy: 0.6126
# Epoch 97/100
# 58/58 [==============================] - 34s 591ms/step - loss: 0.0485 - hamming_loss: 0.0231 - frost_presence_accuracy: 0.9383 - val_loss: 0.6789 - val_hamming_loss: 0.1285 - val_frost_presence_accuracy: 0.5871
# Epoch 98/100
# 58/58 [==============================] - 34s 592ms/step - loss: 0.0504 - hamming_loss: 0.0236 - frost_presence_accuracy: 0.9440 - val_loss: 0.6510 - val_hamming_loss: 0.1135 - val_frost_presence_accuracy: 0.6116
# Epoch 99/100
# 58/58 [==============================] - 34s 594ms/step - loss: 0.0524 - hamming_loss: 0.0251 - frost_presence_accuracy: 0.9372 - val_loss: 0.6511 - val_hamming_loss: 0.1399 - val_frost_presence_accuracy: 0.6098
# Epoch 100/100
# 58/58 [==============================] - 42s 730ms/step - loss: 0.0523 - hamming_loss: 0.0246 - frost_presence_accuracy: 0.9486 - val_loss: 0.5974 - val_hamming_loss: 0.0859 - val_frost_presence_accuracy: 0.6748

# %% [markdown]
# ## Save the weights as a .h5 file
# Also save the history of the model as a .csv file

# %%
import pandas as pd
model.save('vgg16_24_100_1024.h5')
# Convert the history.history dict to a pandas DataFrame
hist_df = pd.DataFrame(history.history)

# Save to csv
hist_csv_file = 'vgg16_24_100_1024.csv'
with open(hist_csv_file, mode='w') as f:
    hist_df.to_csv(f)

# %% [markdown]
# ## Evaluate the model
# Using our custom metrics. Load in the file.

# %%
import pandas as pd
from tensorflow.keras.models import load_model

# Register the custom metric function
with tf.keras.utils.custom_object_scope({'hamming_loss': hamming_loss, 'frost_presence_accuracy': frost_presence_accuracy}):
    my_model = load_model('vgg16_24_100_1024.h5')

my_model_history = pd.read_csv(
    'vgg16_24_100_1024.csv')

# %% [markdown]
# ## Random prediction models (2)
# * Predict all 0's
# * Choose 0's and 1's at random
# * Demonstrates how much better our model is than random

# %%
def predict_zeros(X_data):
    # return an array of [0,0,0,0,0,0] for each X_train
    return np.zeros((X_data.shape[0], 6))

def predict_random(X_data):
    # return an array of random 0's and 1's [x,x,x,x,x,x] for each X_train
    return np.random.choice([0, 1], size=(X_data.shape[0], 6))

# %%
predict_zeros = predict_zeros(X_test)
predict_random = predict_random(X_test)
predictions = my_model.predict(X_test)
# Out:
# 250/250 [==============================] - 21s 73ms/step

# %%
predictions_decimal = np.round(predictions, 2)
predictions_round = np.where(predictions >= 0.6, 1, 0)

# %%
import numpy as np
from keras.models import load_model
from sklearn.metrics import hamming_loss

# Compute the Hamming loss for each predictor
hamming_loss_zeros = hamming_loss(y_test, predict_zeros)
hamming_loss_random = hamming_loss(y_test, predict_random)
hamming_loss_cnn = hamming_loss(y_test, predictions_round)

fp_acc_zeros = frost_presence_accuracy(y_test, predict_zeros)
fp_acc_random = frost_presence_accuracy(y_test, predict_random)
fp_acc_cnn = frost_presence_accuracy(y_test, predictions_round)
# print all
print(f"Hamming Loss for Zeros: {hamming_loss_zeros}")
print(f"Hamming Loss for Random: {hamming_loss_random}")
print(f"Hamming Loss for CNN: {hamming_loss_cnn}")

print(f"Frost Presence Accuracy for Zeros: {fp_acc_zeros}")
print(f"Frost Presence Accuracy for Random: {fp_acc_random}")
print(f"Frost Presence Accuracy for CNN: {fp_acc_cnn}")
# Out:
# Hamming Loss for Zeros: 0.16965629703963875
# Hamming Loss for Random: 0.5035959190500083
# Hamming Loss for CNN: 0.1346378993142666
# Frost Presence Accuracy for Zeros: 0.36615654826164246
# Frost Presence Accuracy for Random: 0.6305820345878601
# Frost Presence Accuracy for CNN: 0.75

# %%
import matplotlib.pyplot as plt

# Create a new figure with a 1x2 grid of subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

# Plot the training and validation Hamming loss on the first subplot
axes[0].plot(my_model_history['hamming_loss'], label='Training Hamming Loss')
axes[0].plot(my_model_history['val_hamming_loss'],
             label='Validation Hamming Loss')

# Label the axes of the first subplot
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Hamming Loss')
axes[0].set_title('Hamming Loss vs. Epochs')

# Add a legend to the first subplot
axes[0].legend()

# Plot the training and validation accuracy on the second subplot
axes[1].plot(my_model_history['frost_presence_accuracy'],
             label="Training Presence Accuracy")
axes[1].plot(my_model_history['val_frost_presence_accuracy'],
             label="Validation Presence Accuracy")

# Label the axes of the second subplot
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Accuracy')
axes[1].set_title('Frost Presence Accuracy vs. Epochs')

# Add a legend to the second subplot
axes[1].legend()

# Display the plot
plt.tight_layout()
plt.show()
